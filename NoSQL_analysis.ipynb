# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Out:
# 41

# %%
# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4561e7c62f8f90daf67'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
twenty_hygiene_df = pd.DataFrame(list(results))
# Display the number of rows in the DataFrame
print(len(twenty_hygiene_df))
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
twenty_hygiene_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64aee4561e7c62f8f90daf67   110681                  0
# 1  64aee4561e7c62f8f90db2e8   612039                  0
# 2  64aee4561e7c62f8f90db5f2   730933                  0
# 3  64aee4561e7c62f8f90db7e0   172735                  0
# 4  64aee4561e7c62f8f90db7ef   172953                  0
# 5  64aee4561e7c62f8f90dc18d   512854                  0
# 6  64aee4561e7c62f8f90dc3c5  1537089                  0
# 7  64aee4571e7c62f8f90dd8da   155648                  0
# 8  64aee4571e7c62f8f90ddd1d  1012883                  0
# 9  64aee4571e7c62f8f90de530   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Query all rows with LocalAuthorityName as London and RatingValue >= 4
query = {
    "LocalAuthorityName": "London",
    "RatingValue": {"$gte": 4}
}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Out:
# 0

# %% [markdown]
# Since there are no instances where the LocalAuthorityName is London, I am applying a different approach to find establishments in London.

# %%
# Use distinct to list all unique values in LocalAuthorityName
unique_local_authorities = establishments.distinct("LocalAuthorityName")

# Print the unique values
for local_authority in unique_local_authorities:
    print(local_authority)
# Out:
# Aberdeenshire
# Arun
# Ashford
# Babergh
# Barking and Dagenham
# Basildon
# Bexley
# Braintree
# Brentwood
# Bromley
# Broxbourne
# Canterbury City
# Castle Point
# Chelmsford
# City of London Corporation
# Colchester
# Dartford
# Dorset
# East Hertfordshire
# East Renfrewshire
# East Suffolk
# Eastbourne
# Epping Forest
# Folkestone and Hythe
# Gravesham
# Greenwich
# Hackney
# Harlow
# Hastings
# Havering
# Ipswich
# Kensington and Chelsea
# Knowsley
# Lambeth
# Lewes
# Lewisham
# Maidstone
# Maldon
# Medway
# Mid Sussex
# Newham
# North Hertfordshire
# North Norfolk
# Orkney Islands
# Pendle
# Reading
# Redbridge
# Rochford
# Rother
# Rushmoor
# Salford
# Sevenoaks
# Slough
# South Cambridgeshire
# Southend-On-Sea
# Spelthorne
# Stratford-on-Avon
# Sunderland
# Swale
# Tandridge
# Tendring
# Thanet
# Thurrock
# Tonbridge and Malling
# Tower Hamlets
# Tunbridge Wells
# Uttlesford
# Waltham Forest
# Wealden
# West Suffolk
# York

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.

# List of local authorities in London
london_authorities = ["Barking and Dagenham", "Bexley", "Brentwood", "Bromley", "Broxbourne", "City of London Corporation",
                      "Greenwich", "Hackney", "Havering", "Kensington and Chelsea", "Lambeth", "Lewisham",
                      "Maldon", "Medway", "Newham", "Redbridge", "Rochford", "Salford", "Sevenoaks",
                      "Southend-On-Sea", "Tower Hamlets", "Waltham Forest"]

# Create the same query
query = {
    "LocalAuthorityName": {"$in": london_authorities},
    "RatingValue": {"$gte": 4}
}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Out:
# 12110

# %%
# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': '37 Bellegrove Road',
#  'AddressLine2': 'Welling',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Espresso Bar',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4610.924647732765,
#  'FHRSID': 329640,
#  'LocalAuthorityBusinessID': '17170/0037/1/000',
#  'LocalAuthorityCode': '503',
#  'LocalAuthorityEmailAddress': 'food.safety@bexley.gov.uk',
#  'LocalAuthorityName': 'Bexley',
#  'LocalAuthorityWebSite': 'http://www.bexley.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'DA16 3PD',
#  'RatingDate': '2021-12-02T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4551e7c62f8f90dab23'),
#  'geocode': {'latitude': 51.1696586608887, 'longitude': 0.758300006389618},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/329640',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 5, 'Structural': 5}}

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(list(results))
# Display the number of rows in the DataFrame
print(len(london_df))
# Out:
# 55

# %%
# Display the first 10 rows of the DataFrame
london_df.head(10)
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  64aee4551e7c62f8f90dab23  329640                  0
# 1  64aee4551e7c62f8f90dab27  329451                  0
# 2  64aee4561e7c62f8f90dbb8d  786143                  0
# 3  64aee4561e7c62f8f90dbb9d  732146                  0
# 4  64aee4561e7c62f8f90dbba0  683387                  0
# 5  64aee4561e7c62f8f90dbba2  786142                  0
# 6  64aee4561e7c62f8f90dbbb6  656594                  0
# 7  64aee4561e7c62f8f90dbbe4  513165                  0
# 8  64aee4561e7c62f8f90dbc00  709274                  0
# 9  64aee4561e7c62f8f90dbc01  512819                  0
#
#   LocalAuthorityBusinessID              BusinessName  \
# 0         17170/0037/1/000              Espresso Bar
# 1              11/00133/CP                     Tesco
# 2             PI/000146385               Moto Medway
# 3             PI/000250266                  WH Smith
# 4             PI/000148604                     Costa
# 5             PI/000146383               Moto Medway
# 6             PI/000248817             Baxtor Storey
# 7           12/01241/RESHO                  Longmans
# 8           14/01150/BAKER       The Garrison Bakery
# 9          12/00776/RESTIN  Khan Tandoori Restaurant
#
#                             BusinessType  BusinessTypeID  \
# 0                Restaurant/Cafe/Canteen               1
# 1  Retailers - supermarkets/hypermarkets            7840
# 2                      Retailers - other            4613
# 3                      Retailers - other            4613
# 4                Restaurant/Cafe/Canteen               1
# 5                      Retailers - other            4613
# 6                Restaurant/Cafe/Canteen               1
# 7                        Caring Premises               5
# 8                      Retailers - other            4613
# 9                Restaurant/Cafe/Canteen               1
#
#                         AddressLine1                            AddressLine2  \
# 0                 37 Bellegrove Road                                 Welling
# 1                      Northend Road                                   Erith
# 2             London Bound Forecourt  Farthing Corner Motorway Services Area
# 3  Farthing Corner Motorway Services  Farthing Corner Motorway Services Area
# 4                      Moto Services  Farthing Corner Motorway Services Area
# 5              Dover Bound Forecourt  Farthing Corner Motorway Services Area
# 6                Grain Power Station                      Power Station Road
# 7                  11 Rampart Street                            Shoeburyness
# 8                     12 High Street                            Shoeburyness
# 9                     16 High Street                            Shoeburyness
#
#       AddressLine3  ...       LocalAuthorityWebSite  \
# 0             Kent  ...    http://www.bexley.gov.uk
# 1             Kent  ...    http://www.bexley.gov.uk
# 2          Rainham  ...   http://www.medway.gov.uk/
# 3          Rainham  ...   http://www.medway.gov.uk/
# 4          Rainham  ...   http://www.medway.gov.uk/
# 5          Rainham  ...   http://www.medway.gov.uk/
# 6    Isle Of Grain  ...   http://www.medway.gov.uk/
# 7  Southend-On-Sea  ...  http://www.southend.gov.uk
# 8  Southend-On-Sea  ...  http://www.southend.gov.uk
# 9  Southend-On-Sea  ...  http://www.southend.gov.uk
#
#             LocalAuthorityEmailAddress  \
# 0            food.safety@bexley.gov.uk
# 1            food.safety@bexley.gov.uk
# 2          foodandsafety@medway.gov.uk
# 3          foodandsafety@medway.gov.uk
# 4          foodandsafety@medway.gov.uk
# 5          foodandsafety@medway.gov.uk
# 6          foodandsafety@medway.gov.uk
# 7  EnvironmentalHealth@southend.gov.uk
# 8  EnvironmentalHealth@southend.gov.uk
# 9  EnvironmentalHealth@southend.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.758300006389618, 'latitude': 5...
# 1  {'longitude': 0.758300006389618, 'latitude': 5...
# 2   {'longitude': 0.6093662, 'latitude': 51.3410609}
# 3   {'longitude': 0.6081663, 'latitude': 51.3415684}
# 4   {'longitude': 0.6081663, 'latitude': 51.3415684}
# 5   {'longitude': 0.6083765, 'latitude': 51.3420157}
# 6  {'longitude': 0.714550971984863, 'latitude': 5...
# 7     {'longitude': 0.795728, 'latitude': 51.528966}
# 8     {'longitude': 0.795072, 'latitude': 51.529315}
# 9     {'longitude': 0.795072, 'latitude': 51.529315}
#
#       Distance NewRatingPending  \
# 0  4610.924648            False
# 1  4610.924648            False
# 2  4622.720793            False
# 3  4622.783311            False
# 4  4622.783311            False
# 5  4622.792251            False
# 6  4622.873638            False
# 7  4622.951669            False
# 8  4622.988426            False
# 9  4622.988426            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'https://api.ratings....
# 8  [{'rel': 'self', 'href': 'https://api.ratings....
# 9  [{'rel': 'self', 'href': 'https://api.ratings....
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
    "RatingValue": 5
}

sort = [("establishments.RatingValue", -1)] 

results = establishments.find(query).sort(sort).limit(5)
results_list = list(results)

# Print the results
for result in results_list:
    pprint(result)
# Out:
# {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4646.95593107927,
#  'FHRSID': 1380578,
#  'LocalAuthorityBusinessID': '14425',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SE',
#  'RatingDate': '2021-11-11T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4581e7c62f8f90e07a8'),
#  'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Plumstead Manor Nursery',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4646.9740101340385,
#  'FHRSID': 695241,
#  'LocalAuthorityBusinessID': 'PI/000179088',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '2021-06-16T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4581e7c62f8f90e07df'),
#  'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}
# {'AddressLine1': '152 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.930146257832,
#  'FHRSID': 1069652,
#  'LocalAuthorityBusinessID': 'PI/000206841',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2020-10-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4581e7c62f8f90e0773'),
#  'geocode': {'latitude': 51.4870351, 'longitude': 0.0927429},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1069652',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
# {'AddressLine1': '144 - 146 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Iceland',
#  'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  'ChangesByServerID': 0,
#  'Distance': 4646.946071297699,
#  'FHRSID': 695223,
#  'LocalAuthorityBusinessID': 'PI/000178842',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-11-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4581e7c62f8f90e0796'),
#  'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64aee4581e7c62f8f90e07c4'),
#  'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert result to Pandas DataFrame
top_5_df = pd.DataFrame(results_list)
top_5_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64aee4581e7c62f8f90e07a8  1380578                  0
# 1  64aee4581e7c62f8f90e07df   695241                  0
# 2  64aee4581e7c62f8f90e0773  1069652                  0
# 3  64aee4581e7c62f8f90e0796   695223                  0
# 4  64aee4581e7c62f8f90e07c4   694609                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0                    14425  Howe and Co Fish and Chips - Van 17
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 3             PI/000178842                              Iceland
# 4             PI/000116619                            Volunteer
#
#                             BusinessType  BusinessTypeID  \
# 0                         Mobile caterer            7846
# 1                        Caring Premises               5
# 2                Restaurant/Cafe/Canteen               1
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                      Pub/bar/nightclub            7843
#
#                                         AddressLine1 AddressLine2  \
# 0  Restaurant And Premises 107A Plumstead High St...
# 1               Plumstead Manor School Old Mill Road
# 2                          152 Plumstead High Street
# 3                    144 - 146 Plumstead High Street
# 4                    130 - 132 Plumstead High Street
#
#   AddressLine3  ...             LocalAuthorityWebSite  \
# 0    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 1    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 2    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 3    Plumstead  ...  http://www.royalgreenwich.gov.uk
# 4    Plumstead  ...  http://www.royalgreenwich.gov.uk
#
#      LocalAuthorityEmailAddress  \
# 0  health@royalgreenwich.gov.uk
# 1  health@royalgreenwich.gov.uk
# 2  health@royalgreenwich.gov.uk
# 3  health@royalgreenwich.gov.uk
# 4  health@royalgreenwich.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0  {'longitude': 0.0925370007753372, 'latitude': ...
# 1  {'longitude': 0.0859939977526665, 'latitude': ...
# 2   {'longitude': 0.0927429, 'latitude': 51.4870351}
# 3  {'longitude': 0.0924199968576431, 'latitude': ...
# 4     {'longitude': 0.09208, 'latitude': 51.4873437}
#
#       Distance NewRatingPending  \
# 0  4646.955931            False
# 1  4646.974010            False
# 2  4646.930146            False
# 3  4646.946071            False
# 4  4646.965635            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Match establishments with a hygiene score of 0
match_query = {"$match": {"scores.Hygiene": 0}}

# Group the matches by Local Authority
group_query = {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}}

# Sort the matches from highest to lowest
sort_values = {"$sort": {"count": -1}}

# Create pipeline
pipeline = [match_query, group_query, sort_values]
results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(len(result))
# Out:
# 28

# %%
# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
zero_hygiene_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(len(zero_hygiene_df))
# Out:
# 55

# %%
# Display the first 10 rows of the DataFrame
zero_hygiene_df
# Out:
#                            _id  count
# 0                       Thanet   1130
# 1                    Greenwich    882
# 2                    Maidstone    713
# 3                       Newham    711
# 4                        Swale    686
# 5                   Chelmsford    680
# 6                       Medway    672
# 7                       Bexley    607
# 8              Southend-On-Sea    586
# 9                     Tendring    542
# 10                  Colchester    498
# 11             Tunbridge Wells    491
# 12        Folkestone and Hythe    480
# 13                  Eastbourne    478
# 14                    Hastings    464
# 15                     Bromley    460
# 16                     Ashford    427
# 17                    Havering    397
# 18                    Dartford    383
# 19                   Braintree    382
# 20                    Basildon    362
# 21                   Gravesham    339
# 22       Tonbridge and Malling    325
# 23                    Thurrock    313
# 24        Barking and Dagenham    301
# 25             Canterbury City    298
# 26                   Brentwood    285
# 27                Castle Point    281
# 28                      Harlow    274
# 29                  Uttlesford    251
# 30                       Lewes    250
# 31                   Sevenoaks    223
# 32                      Maldon    197
# 33          East Hertfordshire    189
# 34                    Rochford    187
# 35                   Redbridge    182
# 36               Epping Forest    180
# 37                East Suffolk    159
# 38              Waltham Forest    110
# 39                     Babergh     97
# 40                     Wealden     93
# 41                      Rother     80
# 42                    Lewisham     65
# 43                   Tandridge     42
# 44  City of London Corporation     28
# 45                     Ipswich     21
# 46               Tower Hamlets      9
# 47         North Hertfordshire      6
# 48                  Mid Sussex      5
# 49                      Dorset      1
# 50                  Broxbourne      1
# 51               North Norfolk      1
# 52                  Sunderland      1
# 53      Kensington and Chelsea      1
# 54                     Reading      1
